# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style='white', color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
population2021 = pd.read_excel('2000_2021.xlsx', sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)
population2020 = pd.read_excel('2000_2021.xlsx', sheet_name=1, header=0, names=None, index_col=None, usecols=None, squeeze=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)
population2019 = pd.read_excel('2000_2021.xlsx', sheet_name=2, header=0, names=None, index_col=None, usecols=None, squeeze=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)
population2018 = pd.read_excel('2000_2021.xlsx', sheet_name=3, header=0, names=None, index_col=None, usecols=None, squeeze=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)
population2017 = pd.read_excel('2000_2021.xlsx', sheet_name=4, header=0, names=None, index_col=None, usecols=None, squeeze=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=None, mangle_dupe_cols=True, storage_options=None)

# %%
population2021
# Out:
#    ЧИСЛЕННОСТЬ НАСЕЛЕНИЯ КАЛИНИНГРАДСКОЙ ОБЛАСТИ НА 01.01.2021 г. ПО ПОЛУ И ВОЗРАСТНЫМ ГРУППАМ (человек)  \
# 0         Административно-территориальные образования
# 1                                                 NaN
# 2                                                 NaN
# 3                                    Всего по области
# 4                                  ГО  г. Калининград
# 5                                    ГО  г. Ладушкин
# 6                                    ГО  г. Мамоново
# 7                                   ГО  г. Пионерский
# 8                                      Светловский ГО
# 9                                      ГО  г. Советск
# 10                                    ГО  п. Янтарный
# 11                                 Багратионовский ГО
# 12                                      Балтийский ГО
# 13                                     Гвардейский ГО
# 14                                      Гурьевский ГО
# ...

# %%
all_population2021 = population2021.iloc[3:, 1:2]
all_population2020 = population2020.iloc[3:, 1:2]
all_population2019 = population2019.iloc[3:, 1:2]
all_population2018 = population2018.iloc[3:, 1:2]
all_population2017 = population2017.iloc[4:, 0:2]

print(all_population2017, all_population2018, all_population2019, all_population2020, all_population2021)
# Out:
#    ЧИСЛЕННОСТЬ НАСЕЛЕНИЯ КАЛИНИНГРАДСКОЙ ОБЛАСТИ НА 01.01.2017 г. ПО ПОЛУ И ВОЗРАСТНЫМ ГРУППАМ (человек)  \
# 4                                    Всего по области
# 5                                  ГО  г. Калининград
# 6                                    ГО  г. Ладушкин
# 7                                    ГО  г. Мамоново
# 8                                   ГО  г. Пионерский
# 9                                      Светловский ГО
# 10                                     ГО  г. Советск
# 11                                    ГО  п. Янтарный
# 12                                 Багратионовский ГО
# 13                                    МР  Балтийский
# 14                                     Гвардейский ГО
# 15                                      Гурьевский ГО
# 16                                       Гусевский ГО
# 17                                  Зеленоградский ГО
# 18                                Краснознаменский ГО
# ...

# %%
import sklearn

# %%
all_population2017.rename(columns={'ЧИСЛЕННОСТЬ НАСЕЛЕНИЯ КАЛИНИНГРАДСКОЙ ОБЛАСТИ НА 01.01.2017 г. ПО ПОЛУ И ВОЗРАСТНЫМ ГРУППАМ (человек)': 'Области'}, inplace=True)

# %%
all_population2017.rename(columns={'Unnamed: 1': 'Население в 2017'}, inplace=True)
all_population2018.rename(columns={'Unnamed: 1': 'Население в 2018'}, inplace=True)
all_population2019.rename(columns={'Unnamed: 1': 'Население в 2019'}, inplace=True)
all_population2020.rename(columns={'Unnamed: 1': 'Население в 2020'}, inplace=True)
all_population2021.rename(columns={'Unnamed: 1': 'Население в 2021'}, inplace=True)

# %%
all_population2017
# Out:
#                  Области Население в 2017
# 4       Всего по области           986261
# 5     ГО  г. Калининград           467289
# 6       ГО  г. Ладушкин              4088
# 7       ГО  г. Мамоново              8247
# 8      ГО  г. Пионерский            11352
# 9         Светловский ГО            29049
# 10        ГО  г. Советск            40486
# 11       ГО  п. Янтарный             6438
# 12    Багратионовский ГО            33101
# 13       МР  Балтийский             36553
# 14        Гвардейский ГО            29231
# 15         Гурьевский ГО            64676
# 16          Гусевский ГО            37557
# 17     Зеленоградский ГО            35754
# 18   Краснознаменский ГО            12196
# 19     МР Светлогорский             17158
# 20          Неманский ГО            19075
# 21      МР Нестеровский             15336
# 22           Озёрский ГО            14051
# 23          Полесский ГО            18461
# 24        Правдинский ГО            19102
# ...

# %%
all_population2017 = all_population2017.reset_index(drop=True)
all_population2018 = all_population2018.reset_index(drop=True)
all_population2019 = all_population2019.reset_index(drop=True)
all_population2020 = all_population2020.reset_index(drop=True)
all_population2021 = all_population2021.reset_index(drop=True)

# %%
#all_population2021

# %%
child_population2021 = population2021.iloc[3:, 5:6]
child_population2020 = population2020.iloc[3:, 5:6]
child_population2019 = population2019.iloc[3:, 5:6]
child_population2018 = population2018.iloc[3:, 5:6]
child_population2017 = population2017.iloc[4:, 5:6]

# %%
child_population2021 = child_population2021.reset_index(drop=True)
child_population2020 = child_population2020.reset_index(drop=True)
child_population2019 = child_population2019.reset_index(drop=True)
child_population2018 = child_population2018.reset_index(drop=True)
child_population2017 = child_population2017.reset_index(drop=True)

# %%
child_population2017.rename(columns={'Unnamed: 5': 'Дети в 2017'}, inplace=True)
child_population2021.rename(columns={'Unnamed: 5': 'Дети в 2021'}, inplace=True)
child_population2020.rename(columns={'Unnamed: 5': 'Дети в 2020'}, inplace=True)
child_population2019.rename(columns={'Unnamed: 5': 'Дети в 2019'}, inplace=True)
child_population2018.rename(columns={'Unnamed: 5': 'Дети в 2018'}, inplace=True)

# %%
child_population2021
# Out:
#    Дети в 2021
# 0       201222
# 1        95618
# 2          758
# 3         1681
# 4         2519
# 5         5343
# 6         6884
# 7         1119
# 8         7343
# 9         6477
# 10        5939
# 11       14068
# 12        7357
# 13        7513
# 14        2717
# 15        3572
# 16        4089
# 17        3257
# 18        3233
# 19        3776
# 20        4374
# 21        4031
# 22        9554

# %%
child20_21 = pd.merge(child_population2020, child_population2021, left_index=True, right_index=True)
child19_21 = pd.merge(child_population2019, child20_21, left_index=True, right_index=True)
child18_21 = pd.merge(child_population2018, child19_21, left_index=True, right_index=True)
df_children_population_17_21 = pd.merge(child_population2017, child18_21, left_index=True, right_index=True)
all20_21 = pd.merge(all_population2020,all_population2021, left_index=True, right_index=True)
all29_21 = pd.merge(all_population2019,all20_21, left_index=True, right_index=True)
all28_21 = pd.merge(all_population2018,all29_21, left_index=True, right_index=True)
df_all_population_17_21 = pd.merge(all_population2017,all28_21, left_index=True, right_index=True)
df_final = pd.merge(df_all_population_17_21, df_children_population_17_21, left_index=True, right_index=True)

# %%
#print(type(child_population2021))

# %%
df_final
# Out:
#                  Области Население в 2017 Население в 2018 Население в 2019  \
# 0       Всего по области           986261           994599          1002187
# 1     ГО  г. Калининград           467289           475056           482443
# 2       ГО  г. Ладушкин              4088             4020             3960
# 3       ГО  г. Мамоново              8247             8140             8169
# 4      ГО  г. Пионерский            11352            11312            11454
# 5         Светловский ГО            29049            28817            28614
# 6         ГО  г. Советск            40486            39752            39150
# 7        ГО  п. Янтарный             6438             6491             6475
# 8     Багратионовский ГО            33101            33177            32786
# 9        МР  Балтийский             36553            36735            37037
# 10        Гвардейский ГО            29231            29258            29144
# ...

# %%
#df_final.iloc[0:]['Области']

# %%
#writer = pd.ExcelWriter('Population17-21.xlsx')
#df_final.to_excel(writer,'children17-21')
#writer.save()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Области           23 non-null     object
#  1   Население в 2017  23 non-null     object
#  2   Население в 2018  23 non-null     object
#  3   Население в 2019  23 non-null     object
#  4   Население в 2020  23 non-null     object
#  5   Население в 2021  23 non-null     object
#  6   Дети в 2017       23 non-null     object
#  7   Дети в 2018       23 non-null     object
#  8   Дети в 2019       23 non-null     object
#  9   Дети в 2020       23 non-null     object
#  10  Дети в 2021       23 non-null     object
# dtypes: object(11)
# memory usage: 2.1+ KB

# %%
df_final['Население в 2017'] = pd.to_numeric(df_final['Население в 2017'], errors='coerce')
df_final['Население в 2018'] = pd.to_numeric(df_final['Население в 2018'], errors='coerce')
df_final['Население в 2019'] = pd.to_numeric(df_final['Население в 2019'], errors='coerce')
df_final['Население в 2020'] = pd.to_numeric(df_final['Население в 2020'], errors='coerce')
df_final['Население в 2021'] = pd.to_numeric(df_final['Население в 2021'], errors='coerce')
df_final['Дети в 2017'] = pd.to_numeric(df_final['Дети в 2017'], errors='coerce')
df_final['Дети в 2018'] = pd.to_numeric(df_final['Дети в 2018'], errors='coerce')
df_final['Дети в 2019'] = pd.to_numeric(df_final['Дети в 2019'], errors='coerce')
df_final['Дети в 2020'] = pd.to_numeric(df_final['Дети в 2020'], errors='coerce')
df_final['Дети в 2021'] = pd.to_numeric(df_final['Дети в 2021'], errors='coerce')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Области           23 non-null     object
#  1   Население в 2017  23 non-null     int64
#  2   Население в 2018  23 non-null     int64
#  3   Население в 2019  23 non-null     int64
#  4   Население в 2020  23 non-null     int64
#  5   Население в 2021  23 non-null     int64
#  6   Дети в 2017       23 non-null     int64
#  7   Дети в 2018       23 non-null     int64
#  8   Дети в 2019       23 non-null     int64
#  9   Дети в 2020       23 non-null     int64
#  10  Дети в 2021       23 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.1+ KB

# %%
df_final.head()
# Out:
#               Области  Население в 2017  Население в 2018  Население в 2019  \
# 0    Всего по области            986261            994599           1002187
# 1  ГО  г. Калининград            467289            475056            482443
# 2    ГО  г. Ладушкин               4088              4020              3960
# 3    ГО  г. Мамоново               8247              8140              8169
# 4   ГО  г. Пионерский             11352             11312             11454
#
#    Население в 2020  Население в 2021  Дети в 2017  Дети в 2018  Дети в 2019  \
# 0           1012512           1018624       189099       193387       196716
# 1            489359            493256        84474        87848        91096
# 2              3972              3905          812          805          807
# 3              8199              8292         1724         1695         1699
# 4             12194             12573         2130         2177         2256
#
#    Дети в 2020  Дети в 2021
# ...

# %%
df_final = df_final.drop(index=[0])

# %%
df_final.head()
# Out:
#               Области  Население в 2017  Население в 2018  Население в 2019  \
# 1  ГО  г. Калининград            467289            475056            482443
# 2    ГО  г. Ладушкин               4088              4020              3960
# 3    ГО  г. Мамоново               8247              8140              8169
# 4   ГО  г. Пионерский             11352             11312             11454
# 5      Светловский ГО             29049             28817             28614
#
#    Население в 2020  Население в 2021  Дети в 2017  Дети в 2018  Дети в 2019  \
# 1            489359            493256        84474        87848        91096
# 2              3972              3905          812          805          807
# 3              8199              8292         1724         1695         1699
# 4             12194             12573         2130         2177         2256
# 5             28617             28423         5469         5508         5443
#
#    Дети в 2020  Дети в 2021
# ...

# %%
df_final.describe()
# Out:
#        Население в 2017  Население в 2018  Население в 2019  Население в 2020  \
# count         22.000000         22.000000         22.000000         22.000000
# mean       44830.045455      45209.045455      45553.954545      46023.272727
# std        95525.360024      97192.909016      98781.587517     100243.135656
# min         4088.000000       4020.000000       3960.000000       3972.000000
# 25%        14372.250000      14093.250000      13767.500000      13622.750000
# 50%        19315.500000      19173.500000      18972.500000      19310.500000
# 75%        36353.250000      36654.250000      37049.750000      37430.750000
# max       467289.000000     475056.000000     482443.000000     489359.000000
#
#        Население в 2021   Дети в 2017   Дети в 2018   Дети в 2019  \
# count         22.000000     22.000000     22.000000     22.000000
# mean       46301.090909   8595.409091   8790.318182   8941.636364
# std       101064.747603  17187.416465  17899.478328  18591.077731
# ...

# %% [markdown]
# Библиотеки научных вычислений, такие как NumPy, Pandas и SciPy.
# Библиотеки визуализации, такие как Matplotlib и seaborn.
# Библиотеки алгоритмов, такие как scikit-learn и statsmodels.
#
# Источник: https://pythonpip.ru/osnovy/data-analytics-analitika-dannyh-v-python

# %% [raw]
# Если вы хотите понять, как две переменные изменяются по отношению друг к другу, лучше всего подойдет линия best fit. На графике ниже показано, как best fit отличается среди различных групп данных. Чтобы отключить группировки и просто нарисовать одну линию best fit для всего набора данных, удалите параметр hue='cyl' из sns.lmplot() ниже.

# %%
line_2017 = df_final[["Население в 2017", "Дети в 2017"]]
line_2018 = df_final[["Население в 2018", "Дети в 2018"]]
line_2019 = df_final[["Население в 2019", "Дети в 2019"]]
line_2020 = df_final[["Население в 2020", "Дети в 2020"]]
line_2021 = df_final[["Население в 2021", "Дети в 2021"]]

# %%
plt.plot(line_2017)

# %%
#plt.plot(line_2018)

# %%
#plt.plot(line_2019)

# %%
#plt.plot(line_2020)

# %% [markdown]
# Соотношение детей и взрослых меняется незначительно, тем не менее, за 5 лет имеется тенденция к росту взрослого населения и уменьшению детского в абсолютных числах

# %%
children_2017_2021 = df_final[["Дети в 2017", "Дети в 2018", "Дети в 2019", "Дети в 2020", "Дети в 2021"]]

# %%
#children_2017_2021.plot(kind='bar', figsize=(20,16))
#plt.show()

# %% [raw]
# Растет количество детского населения в городе Калининграде - это столица региона и самый развитый город, также небольшой стабильный прирост детей наблюдаеся в 4 ГО г. Пионерский и 15 МР Светлогорский, заметный прирост - в 11 - Гурьевский ГО. Пионерск и Светлогорск - курортные города, вероятно, поэтому туда переезжают семьи, однако Зеленоградск - равно известный курорт (на чьей территории расположен аэропорт и идет застройка побережья многоэтажными жилыми домами, в Зеленоградск идет максимальное число электричек и муниципального транспорта, с его территории въезжают а парк Куршская коса) дает отрицательную динамику детского населения. Гурьевский рейон на втором месте по количеству детей, он географически примыкает к Калининграду, его жителям доступна инфраструктура города, район получает доходы от федерального кардиоцентра и активно застраивается. Аэропорт Храброво находится по пути из Калининграда в Гурьевск. Транспортная доступность позволяет врачам города Калининграда подрабатывать в поликлиниках Гурьевска.
# В 7 регионах ситуация не меняется. Заметно уменьшилось число детей в 5, 6, 12, 16, 17, 21 районах. В целом, семьи с детьми предпочитают жить в Калининграде и Гурьевске.

# %%
plt.plot(children_2017_2021)

# %%
trans_df = df_final.transpose()

# %%
trans_df
# Out:
#                                   1                 2                 3   \
# Области           ГО  г. Калининград  ГО  г. Ладушкин   ГО  г. Мамоново
# Население в 2017              467289              4088              8247
# Население в 2018              475056              4020              8140
# Население в 2019              482443              3960              8169
# Население в 2020              489359              3972              8199
# Население в 2021              493256              3905              8292
# Дети в 2017                    84474               812              1724
# Дети в 2018                    87848               805              1695
# Дети в 2019                    91096               807              1699
# Дети в 2020                    93778               796              1701
# Дети в 2021                    95618               758              1681
#
#                                  4                5               6   \
# ...

# %% [raw]
# kaliningad = trans_df[[1]]
# ladushkin = trans_df[[2]]
# mamonovo = trans_df[[3]]
# pionerskiy = trans_df[[4]]
# svetliy = trans_df[[5]]
# sovetsk = trans_df[[6]]
# yantarniy = trans_df[[7]]
# bagrationovsk = trans_df[[8]]
# baltiysk =
# gvardeysk =
# zelenogradsk =
# krasnoznamesk =
# svetlogorsk =
# neman =
# nesterov =
# ozersk =
# polessk =
# pravdinsk =
# slavsk =
# chernyachovsk =

# %%
trans_df.describe()
# Out:
#                         1                 2                 3   \
# count                   11                11                11
# unique                  11                11                11
# top     ГО  г. Калининград  ГО  г. Ладушкин   ГО  г. Мамоново
# freq                     1                 1                 1
#
#                        4                5               6                7   \
# count                  11               11              11               11
# unique                 11               11              11               11
# top     ГО  г. Пионерский   Светловский ГО  ГО  г. Советск  ГО  п. Янтарный
# freq                    1                1               1                1
#
#                          8                9                10  ...  \
# count                    11               11               11  ...
# unique                   11               11               11  ...
# ...

# %% [markdown]
# series1 = np.array(line_2017)
# series2 = np.array(line_2017)
# index = np.arange(4)
# plt.axis([0,23, 0, 100000])
# plt.title('Отношение детей и взрослых по годам')
# plt.barh(index,series1,color='r')
# plt.barh(index,series2,color='b',left=series1)
# plt.yticks(index,['2017','2018','2019','2020','2021'])
# plt.show()

# %%
# !pip install plotly

# %%
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots

# %% [raw]
# cities = pd.read_csv('https://raw.githubusercontent.com/hflabs/city/master/city.csv')
# fig = go.Figure(go.Scattermapbox(lat=cities['geo_lat'], lon=cities['geo_lon']))
# fig.update_layout(mapbox_style="open-street-map")
# fig.show()

# %% [raw]
# https://github.com/hflabs/region
# https://www.geonames.org/

# %% [raw]
# geoname_code RU.23 geoname_id 554230 geoname_name Kaliningrad

# %%
# !pip install folium

# %%
import folium

# %%
map = folium.Map(location=[54.750, 21.500], zoom_start=8)
#map.save('kaliningrad.html')

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [raw]
# folium.Marker kaliningad = [54.7065, 20.511]
# ladushkin = [54.57288, 20.17644]
# mamonovo = [54.464, 19.934]
# pionerskiy = [54.951, 20.233]
# svetliy = [54.6775, 20.13167]
# sovetsk = [55.07885, 21.87871]
# yantarniy = [54.87278, 19.94056]
# bagrationovsk = [54.3841, 20.6466]
# baltiysk = [54.655 , 19.911667]
# gvardeysk = [54.65213, 21.06704]
# zelenogradsk = [54.95623, 20.4747]
# krasnoznamesk = [54.942, 22.48719]
# svetlogorsk = [54.93946, 20.15847]
# neman = [55.03333, 22.03333]
# nesterov = [43.23889, 45.05556]
# ozersk = [54.4026, 22.01937]
# polessk = [54.86667, 21.1]
# pravdinsk = [54.44131, 21.01198]
# slavsk = [55.04509, 21.67271]
# chernyachovsk = [54.63127, 21.83114]

# %%
folium.Marker(location=[54.7065, 20.511], popup="Калининград", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.57288, 20.17644], popup="Ладушкин", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.464, 19.934], popup="Мамоново", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.951, 20.233], popup="Пионерский", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.6775, 20.13167], popup="Светлый", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[55.07885, 21.87871], popup="Советск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.87278, 19.94056], popup="Янтарный", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.3841, 20.6466], popup="Багратионовск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.655 , 19.911667], popup="Балтийск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.65213, 21.06704], popup="Гвардейск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.95623, 20.4747], popup="Зеленоградск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.942, 22.48719], popup="Краснознаменск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.93946, 20.15847], popup="Светлогорск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[55.03333, 22.03333], popup="Неман", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[43.23889, 45.05556], popup="Нестеров", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.4026, 22.01937], popup="Озерск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.86667, 21.1], popup="Полесск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.44131, 21.01198], popup="Правдинск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[55.04509, 21.67271], popup="Славск", icon=folium.Icon(color="gray")).add_to(map)
folium.Marker(location=[54.63127, 21.83114], popup="Черняховск", icon=folium.Icon(color="gray")).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import plotly.express as px
df = px.data.gapminder().query("year==2007_2021")
fig = px.scatter_geo(df, locations="iso_alpha", color="country",
                     hover_name="country", size="pop",
                     projection="natural earth")
fig.show()
# Out:
# <div>                            <div id="83aa8e39-1a82-426e-bad3-ba2f9a3c8ba3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83aa8e39-1a82-426e-bad3-ba2f9a3c8ba3")) {                    Plotly.newPlot(                        "83aa8e39-1a82-426e-bad3-ba2f9a3c8ba3",                        [],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"chorople
# ...
